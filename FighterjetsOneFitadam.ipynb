# %%
# !pip install -Uqq fastbook

# %%
import fastbook
fastbook.setup_book()

# %%
from fastbook import *

# %%
path='./data/'

# %%
from PIL import Image

im = Image.open(path + 'F-22_Raptor/image_1.jpg')
im.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x96>

# %%
from fastai.vision.all import *
filenames = get_image_files(path)
filenames
# Out:
# (#846) [Path('data/F-1117_Nighthawk/image_1.jpg'),Path('data/F-1117_Nighthawk/image_10.jpg'),Path('data/F-1117_Nighthawk/image_100.jpg'),Path('data/F-1117_Nighthawk/image_101.jpg'),Path('data/F-1117_Nighthawk/image_102.jpg'),Path('data/F-1117_Nighthawk/image_103.jpg'),Path('data/F-1117_Nighthawk/image_104.jpg'),Path('data/F-1117_Nighthawk/image_105.jpg'),Path('data/F-1117_Nighthawk/image_107.jpg'),Path('data/F-1117_Nighthawk/image_108.jpg')...]

# %% [markdown]
# Sanity check on images. Corrupt images check.

# %%
failed = verify_images(filenames)
failed
# Out:
# (#0) []

# %% [markdown]
# Create own DataLoaders object --> data block API

# %%
# Create a DataBlock
fighterjets = DataBlock(
    blocks=(ImageBlock, CategoryBlock),
    get_items=get_image_files,
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=Resize(460),
    batch_tfms=aug_transforms(size=224, min_scale=0.75))

# %%
dls = fighterjets.dataloaders(path)
# Out:
# d:\school23_24\.venv\lib\site-packages\fastai\torch_core.py:263: UserWarning: 'has_mps' is deprecated, please use 'torch.backends.mps.is_built()'
#   return getattr(torch, 'has_mps', False)

# %% [markdown]
# Show labeled images

# %%
dls.train.show_batch(max_n=4, nrows=1)
dls.valid.show_batch(max_n=4, nrows=1)

# %% [markdown]
# Test model using resnet

# %%
resnet50_model = vision_learner(dls, resnet50, metrics=error_rate, opt_func=Adam)
resnet50_model.fit_one_cycle(5)
resnet50_model.unfreeze()
resnet50_model.fit_one_cycle(15)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.493449</td>
#       <td>1.491867</td>
#       <td>0.550296</td>
#       <td>01:09</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.866720</td>
#       <td>1.006814</td>
#       <td>0.343195</td>
#       <td>01:08</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.518923</td>
#       <td>0.924816</td>
#       <td>0.295858</td>
#       <td>01:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.258947</td>
#       <td>0.874083</td>
#       <td>0.313609</td>
#       <td>01:07</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.080415</td>
#       <td>0.888452</td>
#       <td>0.319527</td>
#       <td>01:06</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.685489</td>
#       <td>0.928013</td>
#       <td>0.289941</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.586566</td>
#       <td>0.753452</td>
#       <td>0.236686</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.498524</td>
#       <td>1.117818</td>
#       <td>0.313609</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.473842</td>
#       <td>1.164059</td>
#       <td>0.337278</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.441958</td>
#       <td>1.465004</td>
#       <td>0.325444</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.422122</td>
#       <td>1.935952</td>
#       <td>0.236686</td>
#       <td>01:22</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.396347</td>
#       <td>2.093329</td>
#       <td>0.313609</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.374747</td>
#       <td>0.889247</td>
#       <td>0.230769</td>
#       <td>01:22</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.343219</td>
#       <td>0.590006</td>
#       <td>0.171598</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.304839</td>
#       <td>0.490437</td>
#       <td>0.130178</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.259140</td>
#       <td>0.403592</td>
#       <td>0.112426</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.226220</td>
#       <td>0.360010</td>
#       <td>0.100592</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.197731</td>
#       <td>0.373076</td>
#       <td>0.118343</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.167566</td>
#       <td>0.377219</td>
#       <td>0.124260</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.149032</td>
#       <td>0.367950</td>
#       <td>0.118343</td>
#       <td>01:22</td>
#     </tr>
#   </tbody>
# </table>

# %%
recorder = resnet50_model.recorder

# Print the training and validation accuracy
train_acc = recorder.values[-1][1]  # Training accuracy (last epoch)
valid_acc = recorder.values[-1][2]  # Validation accuracy (last epoch)

print(f'Training Accuracy: {train_acc:.4f}')
print(f'Validation Accuracy: {valid_acc:.4f}')

# Plot the training and validation accuracy
recorder.plot_loss()
# Out:
# Training Accuracy: 0.3680
# Validation Accuracy: 0.1183

# %%
interp = ClassificationInterpretation.from_learner(resnet50_model)
interp.plot_confusion_matrix()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='0' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/3 00:00&lt;?]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
interp = ClassificationInterpretation.from_learner(our_out_of_the_box_model)
interp.plot_confusion_matrix()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 interp = ClassificationInterpretation.from_learner(our_out_of_the_box_model)
#       2 interp.plot_confusion_matrix()
#
# NameError: name 'our_out_of_the_box_model' is not defined

# %%
interp.plot_top_losses(5, nrows=5)
# Out:
# d:\school23_24\.venv\lib\site-packages\fastai\torch_core.py:263: UserWarning: 'has_mps' is deprecated, please use 'torch.backends.mps.is_built()'
#   return getattr(torch, 'has_mps', False)
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
resnet50_model.show_results(max_n=5, figsize=(8,8))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
confusion_matrix  = interp.confusion_matrix()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
accuracies_per_class = np.diag(confusion_matrix) / confusion_matrix.sum(axis=1)

class_names = resnet50_model.dls.vocab

# Print accuracy per class
print('Accuracy per class:')
for i, accuracy in enumerate(accuracies_per_class):
    print(f'{class_names[i]}: {accuracy * 100:.2f}%')
# Out:
# Accuracy per class:
# F-1117_Nighthawk: 89.29%
# F-16_Fighting_Falcon: 71.88%
# F-22_Raptor: 79.55%
# F-4_Phantom: 91.18%
# MiG_29_Fulcrum: 90.32%

# %%
accuracies_per_class = np.diag(confusion_matrix) / confusion_matrix.sum(axis=1)

class_names = resnet50_model.dls.vocab

# Print accuracy per class
print('Accuracy per class:')
for i, accuracy in enumerate(accuracies_per_class):
    print(f'{class_names[i]}: {accuracy * 100:.2f}%')
# Out:
# Accuracy per class:
# F-1117_Nighthawk: 96.43%
# F-16_Fighting_Falcon: 75.00%
# F-22_Raptor: 84.09%
# F-4_Phantom: 91.18%
# MiG_29_Fulcrum: 96.77%

# %%
resnet50_model.export("./models/modelOneCycleBest")

# %%
loaded_model = load_learner("models/modelOneCycle")

# %%
loaded_model.predict(path + 'F-22_Raptor/image_1.jpg')
# Out:
# d:\school23_24\.venv\lib\site-packages\fastai\torch_core.py:263: UserWarning: 'has_mps' is deprecated, please use 'torch.backends.mps.is_built()'
#   return getattr(torch, 'has_mps', False)
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('F-22_Raptor',
#  tensor(2),
#  tensor([2.8992e-05, 5.3671e-07, 9.9988e-01, 5.0434e-07, 8.8926e-05]))

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# %%
preds, targets = resnet50_model.get_preds()

# Check if it's a binary or multi-class problem
num_classes = preds.shape[1]
class_names = resnet50_model.dls.vocab

if num_classes > 1:
    # Convert targets to one-hot encoding for multi-class problems
    targets_onehot = F.one_hot(targets, num_classes=num_classes)
    
    # For multi-class problems, plot ROC-AUC for each class
    for i in range(num_classes):
        fpr, tpr, _ = roc_curve(targets_onehot[:, i], preds[:, i])
        roc_auc = auc(fpr, tpr)

        plt.figure(figsize=(8, 8))
        plt.plot(fpr, tpr, label=f'{class_names[i]} (AUC = {roc_auc:.2f})')
        plt.plot([0, 1], [0, 1], 'k--')
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title(f'ROC Curve - {class_names[i]}')
        plt.legend(loc='lower right')
        plt.show()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
preds, targets = resnet50_model.get_preds()

# Check if it's a binary or multi-class problem
num_classes = preds.shape[1]

class_names = resnet50_model.dls.vocab

auc_values = []

if num_classes > 1:
    # Convert targets to one-hot encoding for multi-class problems
    targets_onehot = F.one_hot(targets, num_classes=num_classes)
    
    # For multi-class problems, compute ROC-AUC for each class
    for i in range(num_classes):
        fpr, tpr, _ = roc_curve(targets_onehot[:, i], preds[:, i])
        roc_auc = auc(fpr, tpr)
        
        auc_values.append((class_names[i], roc_auc))
else:
    # For binary classification problems, compute ROC-AUC
    fpr, tpr, _ = roc_curve(targets, preds)
    roc_auc = auc(fpr, tpr)
    
    auc_values.append((class_names[1], roc_auc))

# Print AUC values
for class_name, auc_value in auc_values:
    print(f'AUC for {class_name}: {auc_value:.4f}')
# Out:
# d:\school23_24\.venv\lib\site-packages\fastai\torch_core.py:263: UserWarning: 'has_mps' is deprecated, please use 'torch.backends.mps.is_built()'
#   return getattr(torch, 'has_mps', False)
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# AUC for F-1117_Nighthawk: 0.9997
# AUC for F-16_Fighting_Falcon: 0.9706
# AUC for F-22_Raptor: 0.9845
# AUC for F-4_Phantom: 0.9869
# AUC for MiG_29_Fulcrum: 0.9935
